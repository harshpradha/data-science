# %%
import matplotlib.pyplot as plt (graph ko repersention karne ke liye yje as a line show katta h)

# %%
# graph in matplotlib
# plot()
# subplot
# bar
# histo
# pie

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
x =[1,2,3,5,5]
y =[1,2,3,5,5]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x =[1,2,3,5,5]
y =[1,2,3,5,5]
plt.plot(x,y)
plt.title("my first plot")
plt.xlabel("power")
plt.ylabel("weak")
# Out:
# Text(0, 0.5, 'weak')

# %%
x =[1,2,3,5,5]
y =[1,2,3,5,5]
plt.plot(x,y)
plt.legend('gandu')(line represention)
plt.title("my first plot")
plt.xlabel("power")
plt.ylabel("weak")
# Out:
# Text(0, 0.5, 'weak')

# %%
x =[1,2,3,5,5]
y =[1,2,3,5,5]

plt.plot(x,y,lw=5 ,ls='dotted',marker='*',mfc='r') 

plt.legend('gandu')
plt.title("my first plot")
plt.xlabel("power")
plt.ylabel("weak")
# Out:
# Text(0, 0.5, 'weak')

# %%
x =[1,2,3,5,5]
y =[1,2,3,5,5]
plt.plot(x,y,lw=5 ,ls='dotted') 
# (line lo dottesd karne ke liye)
plt.legend('gandu')
plt.title("my first plot")
plt.xlabel("power")
plt.ylabel("weak")
# Out:
# Text(0, 0.5, 'weak')

# %%
x=[2,5,9,6,7]
y=[5,8,5,6,2]
plt.legend('gandu')
plt.plot(x,y,lw=5 ,ls='dotted',marker='*',ms=14,mfc='r') 
# marker line ko dark karta h 
# ms line ki size ,mfc under colure fiil karti h mec us ke bahar 
plt.title("my first plot")
plt.xlabel("power")
plt.ylabel("weak")
plt.legend('gandu')
plt.title("my first plot")
plt.xlabel("power")
plt.ylabel("weak")
# Out:
# Text(0, 0.5, 'weak')

# %%
arr=[1,5,8,9,9,]
arr1=[5,9,6,5,2,]
xp=np.array(x)
yp=np.array(y)
plt.show
# (us ke box me show kartye h)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=[1,4,10,8,5]
y=[1,2,9,6,5]
xx=[1,4,11,8,5]
yy=[1,3,10,7,5]
xxx=[4,5,6,9,2]
yyy=[8,5,2,6,9]
xpoint=np.array(x)
ypoint=np.array(y)


plt.subplot(1,2,1)
# (first=is show that row,second is show that column, and third is show thatindexing)
plt.plot(xpoint,ypoint)
xxpoint=np.array(xx)
yypoint=np.array(yy)


plt.subplot(1,2,2)
plt.plot(xxpoint,yypoint)
plt.show()

xxxpoint=np.array(xxx)
yyypoint=np.array(yyy)
plt.subplot(1,3,3)
plt.plot(xxxpoint,yyypoint)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a=[1,5,4,5,9,9]
b=[5,8,5,9,7,3]
x=[5,2,6,9,8,7,45,2,6,2,52,25,25,]
y=[1,5,2,4,5,6,5,8,9,7,5,3,0,]
colure=np.array
apoint=np.array(a)
bpoint=np.array(b)
xpoint=np.array(x)
ypoint=np.array(y)
plt.scatter(xpoint,ypoint)
plt.scatter(apoint,bpoint)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
